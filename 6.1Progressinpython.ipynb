# %%
## Python prompt as calculator

# %%
6*3
# Out:
# 18

# %%
3**3
# Out:
# 27

# %%
6+2*4
# Out:
# 14

# %%
(6+2)*4
# Out:
# 32

# %%
5-3-3
# Out:
# -1

# %%
k=5-(3-3)

# %%
9.0**0.5
# Out:
# 3.0

# %%
(5+3.1)*5
# Out:
# 40.5

# %%
S=5.0 -(3-3.0)

# %%
S
# Out:
# 5.0

# %%
x=12.0/4

# %%
x
# Out:
# 3.0

# %%
7--7--7
# Out:
# 21

# %%
8/6
# Out:
# 1.3333333333333333

# %%
a=8%3

# %%
a
# Out:
# 2

# %%
3**2**0
# Out:
# 3

# %%
(3**2)**0
# Out:
# 1

# %% [markdown]
# a+5

# %%
3.0*0.5
# Out:
# 1.5

# %%
9.0%3
# Out:
# 0.0

# %%
-9.0%4
# Out:
# 3.0

# %%
6.2%4
# Out:
# 2.2

# %%
2<5
# Out:
# True

# %%
3>5 and 5<3
# Out:
# False

# %%
4<3 or 6>7
# Out:
# False

# %%
3<=3
# Out:
# True

# %%
4 !=5
# Out:
# True

# %%
##Display vs printing

# %%
33+23
# Out:
# 56

# %%
"S=24+9"(first assign 24+9 to S and then print (display S))
# Out:
#   Cell In[33], line 1
#     "S=24+9"(first assign 24+9 to S and then print (display S))
#              ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
S = 24 + 9
print(S)
# Out:
# 33

# %%
a=3
b=17
c=b-10
print(a,b,c)
# Out:
# 3 17 7
